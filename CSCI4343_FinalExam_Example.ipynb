# %% [markdown]
# <a href="https://colab.research.google.com/github/rgv-data-miners/CSCI4343-Review/blob/main/CSCI4343_FinalExam_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CSCI4343: Data Mining

# %% [markdown]
# #Q1: Arabica or Robusta?

# %% [markdown]
# **Q1**: Suppose you are a coffee business owner and need to decide which coffee bean you plan to import. There are two types of coffee beans: arabica and robusta. Usually, arabica is more expensive. Now, you are considering buy some green bean (unroasted coffee) from one green bean importer. They claimed that the coffee bean is arabica but you suspect that it is robusta after roast and brew the sample.
#
# Luckily, you have a spectrum analysis machine and your friend provides 4 bags of coffee beans, 2 are robusta and 2 are arabica. So you decide to build a data mining model to identify the sample provided the green bean importer

# %% [markdown]
# ##Known Arabica Sample

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Known Robusta Sample

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **(a)** Remember our classical Katydid vs. Grasshopper example, the first step is extract useful feature that can be process by the model. Which feature you will use to design the problem? Please clearly mentioned it.
#
# **(b)** Based on the idea of loglikeihood loss function. Please write down the model equations and the loss function. (You do not need to compute the value or perform gradient descend)

# %% [markdown]
# #Q2: Consider a table consists of the following features of wine:
#
# x1: Color (Red, Transparent)
#
# x2: Today is Monday (Yes, No)
#
# x3: Today is Tuesday (Yes, No)
#
# x4: Today is Wednesday (Yes, No)
#
# x5: Today is Thursday (Yes, No)
#
# x6: Today is Friday (Yes, No)
#
# x7: Today is a sunny day (Yes, No)
#
# x8: Today is a rainy day (Yes, No)
#
#
# Given such a dataset, which data mining model (linear classification, support vector machine, naive bayes) will work better? Please clearly state the reason. Hint: Please write down a simple dataset and the decision make process, then answer the question.

# %% [markdown]
# #Q3: Likeihood Loss
#
# Consider the following data
#
#
# Feature A | Feature B | Class
#
# 110       | 10        | A
#
# 75        | 80        | B
#
# 32        | 60        | B
#
# 11        | 20        | A
#
#
# Suppose we do not want to directly model the data through gaussian distribution (like the one we talked in the class). Instead, we want to use discrete variable to model this data. To do so, we transfer the data based on the following rules:
#
# Rule 1: if Feature A > 60, Generate New Feature A = 1, otherwise 0
#
# Rule 2: if Feature B > 50, Generate New Feature B = 1, otherwise 0

# %% [markdown]
# ##Question:

# %% [markdown]
# **(a)** Write down the modified dataset. What is the data looks like after transformation
#
# **(b)** Suppose we model each dimension through a bernoulli distribution where $p_A$ is the parameter for Feature A and $p_B$ is the parameter for Feature B. Write down the log likeihood loss function
#
# **(c)** Draw the decision boundary of model (b). Is it a linear classifier?

# %% [markdown]
# #Q4: How many parameters in the following model:
#
# **(a)** A linear classification model with input of 100 dimensional data
#
# **(b)** A support vector machine model with input of 200 dimensional data
#
# **(c)** A naive bayes model with input of 1000 dimensional data

# %% [markdown]
# #Q5: Overfitting and Underfitting
#
# We know that cross vaildation is important to data mining models. For the following model, given the data's decision boundary is described by the equation:$|x-y|<4$ for class A, otherwise class B. Answer whether model will potentially overfitting, underfitting, or almost  the data:
#
# **(a)** Use a linear classifier
#
# **(b)** Use a support classifier with transformation $u=x^2$ and $v=y^2$.
#
# **(c)** Can you design a model that perfectly fit the boundary?
